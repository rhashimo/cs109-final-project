# %%
#RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get(
    "https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css"
).text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #fce8e8;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
# ...

# %%
import re
import requests
from time import sleep
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid')
pd.set_option('display.width', 1500)

# %% [markdown]
# ## Data Set

# %%
# Load data
df = pd.read_csv('data/df_fifa.csv')

# %%
df.head()
# Out:
#    sofifa_id         short_name  age         dob  height_cm  weight_kg  nationality                 club  overall  value_eur  ...  ab_mentality_composure ab_defending_marking  ab_defending_standing_tackle  ab_defending_sliding_tackle ab_goalkeeping_diving ab_goalkeeping_handling  ab_goalkeeping_kicking ab_goalkeeping_positioning  ab_goalkeeping_reflexes d_foot_left
# 0     158023           L. Messi   27  1987-06-24        169         67    Argentina         FC Barcelona       93          0  ...                     NaN                   25                            21                           20                     6                      11                      15                         14                        8           1
# ...

# %%
list(df.columns)
# Out:
# ['sofifa_id',
#  'short_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'value_eur',
#  'wage_eur',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'work_rate',
#  'body_type',
#  'release_clause_eur',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'year',
#  'league_name',
#  'd_trait_Avoids_Using_Weaker_Foot',
#  'd_trait_Beat_Offside_Trap',
#  'd_trait_Finesse_Shot',
#  'd_trait_Long_Throw-in',
#  'd_trait_Through_Ball',
#  'd_trait_Takes_Finesse_Free_Kicks',
#  'd_trait_Power_Header',
#  'd_trait_Injury_Free',
#  'd_trait_Crowd_Favourite',
#  'd_trait_1-on-1_Rush',
#  'd_trait_Flair',
#  'd_trait_Outside_Foot_Shot',
#  'd_trait_Inflexible',
#  'd_trait_Giant_Throw-in',
#  'd_trait_Cautious_With_Crosses',
#  'd_trait_Saves_with_Feet',
#  'd_trait_Puncher',
#  'd_trait_Rushes_Out_Of_Goal',
#  'd_trait_Skilled_Dribbling',
# ...

# %%
df['short_name'].head(20)
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             A. Robben
# 3        Z. Ibrahimović
# 4              M. Neuer
# 5             L. Suárez
# 6             E. Hazard
# 7         R. van Persie
# 8     B. Schweinsteiger
# 9             F. Ribéry
# 10               Falcao
# 11              G. Bale
# 12       R. Lewandowski
# 13              P. Lahm
# 14         Sergio Ramos
# 15         Thiago Silva
# 16          David Silva
# 17            L. Modrić
# 18         J. Rodríguez
# 19               Neymar
# Name: short_name, dtype: object

# %% [markdown]
# ## EDA

# %% [markdown]
# Filtering by year 2020

# %%
df_20 = df[df['year'] != 2020]

# %% [markdown]
# Height Distribution

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
sns.kdeplot(df_20.height_cm, ax=ax)
ax.set(xlabel='Height', title='Distribution of height (in cm), 2015 - 2020')
# Out:
# [Text(0.5, 0, 'Height'),
#  Text(0.5, 1.0, 'Distribution of height (in cm), 2015 - 2020')]

# %% [markdown]
# Age Distribution

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
sns.kdeplot(df_20.age, ax=ax, hue = df_20['preferred_foot'] )
ax.set(xlabel='Age', title='Distribution of age, 2015 - 2020')
# Out:
# [Text(0.5, 0, 'Age'), Text(0.5, 1.0, 'Distribution of age, 2015 - 2020')]

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(df_20.overall,df_20.wage_eur)
ax.set_xlabel("Overall Score")
ax.set_ylabel("Wage")
# Out:
# Text(0, 0.5, 'Wage')

# %%
colors = {'Left':'red', 'Right':'blue'}
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(df_20['overall'],df_20['wage_eur'], c = df_20['preferred_foot'].map(colors))
ax.set_xlabel("Overall Score")
ax.set_ylabel("Wage")
# Out:
# Text(0, 0.5, 'Wage')

# %%
sns.scatterplot('overall', 'wage_eur', data=df_20, hue='preferred_foot')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
colors = {'Left':'red', 'Right':'blue'}
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(df_20['value_eur'],df_20['overall'], c = df_20['preferred_foot'].map(colors))
ax.set_xlabel("Overall Score")
ax.set_ylabel("Wage")
# Out:
# Text(0, 0.5, 'Wage')

# %%
club_group = df_20.groupby(by = ['club']).mean()

# %%
sns.kdeplot(data=df_20, x=df_20['wage_eur'], hue='preferred_foot', legend=True)

# %%
foot_group = df_20.groupby(by = ['preferred_foot']).mean()

# %%
foot_group[['overall', 'wage_eur']].describe()
# Out:
#          overall     wage_eur
# count   2.000000     2.000000
# mean   65.886808  9163.040390
# std     0.443684   341.562448
# min    65.573076  8921.519266
# 25%    65.729942  9042.279828
# 50%    65.886808  9163.040390
# 75%    66.043674  9283.800951
# max    66.200540  9404.561513

# %%
plt.bar(np.arange(2),foot_group['wage_eur'])
plt.xticks(np.arange(2), ('Left', 'Right'))
# Out:
# ([<matplotlib.axis.XTick at 0x7fd461df7970>,
# ...
#  [Text(0, 0, 'Left'), Text(0, 0, 'Right')])

# %%
league_group = df_20.groupby(by = ['league_name']).mean()

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(league_group['value_eur'],league_group['overall'], s = league_group['wage_eur']/100)
ax.set_xlabel("Value")
ax.set_ylabel("Overall Score")
# Out:
# Text(0, 0.5, 'Overall Score')

# %% [markdown]
# Which club has the best staff?
# * group by team and calculate means
# * sort from the best overall to the lowest, make a table
# * scatter plot with the overall rating and

# %%
club_group = df_20.groupby(by = ['club']).mean()

# %%
club_group.sort_values(by=['overall'], ascending=False).head(10)
# Out:
#                        sofifa_id        age   height_cm  weight_kg    overall     value_eur       wage_eur  international_reputation  weak_foot  release_clause_eur  ...  ab_mentality_composure  ab_defending_marking  ab_defending_standing_tackle  ab_defending_sliding_tackle  ab_goalkeeping_diving  ab_goalkeeping_handling  ab_goalkeeping_kicking  ab_goalkeeping_positioning  ab_goalkeeping_reflexes  d_foot_left
# club                                                                                                                                                                 ...
# Belgium            177413.000000  28.000000  186.000000  73.000000  82.000000  0.000000e+00       0.000000                  3.000000   3.000000                 NaN  ...               86.000000             69.000000                     73.000000                    71.000000               5.000000                 7.000000                7.000000                   10.000000                 7.000000     0.000000
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(club_group['value_eur'],club_group['overall'])
ax.set_xlabel("Value")
ax.set_ylabel("Overall Score")
#ax.axis([10000, 13000,0,20])
# Out:
# Text(0, 0.5, 'Overall Score')

# %%
df_20['body_type'].describe()
# Out:
# count      82805
# unique        10
# top       Normal
# freq       49090
# Name: body_type, dtype: object

# %%
fig, ax = plt.subplots(figsize = (20,4))
sns.barplot(x="body_type", y="value_eur", ax = ax, hue="preferred_foot", data=df_20)

# %%
year_group = df_20.groupby(by = ['year']).sum()

# %%
sns.lineplot(data=year_group, x="year", y="overall")

# %%
sns.lineplot(data=year_group, x="year", y="value_eur")

# %%
sns.lineplot(data=year_group, x="year", y="wage_eur")

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(club_group['wage_eur'],club_group['value_eur'], s = club_group['overall'])
ax.set_xlabel("Wage")
ax.set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
new_df = df_20.groupby(by="league_name"). count().sort_values(by='value_eur', ascending=False)
new_df

# %%
new_df = df_20.groupby(by="preferred_foot").median().sort_values(by='overall', ascending=False)
new_df

# %%
df_20.describe()

# %%
fig, ax = plt.subplots(1, 1, figsize = (10, 6))
ax.scatter(club_group['value_eur'],club_group['overall'], s = club_group['wage_eur']/1000)
ax.set_xlabel("Wage")
ax.set_ylabel("Value")

# %% [markdown]
# Top ten nationalities by value

# %%
top_nat = df_20.groupby(by="nationality").median().sort_values(by='overall', ascending=False)
top_nat.head(10)

# %%
top_nat2 = df_20.groupby(by="nationality").median().sort_values(by='international_reputation', ascending=False)
top_nat2.head(30)
